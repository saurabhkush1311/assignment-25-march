# %% [markdown]
# ### Flight Price Dataset

# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions:

# %%
import pandas as pd
data = "flight_price.xlsx"

flight_data = pd.read_excel(data)

# Examine dimensions
rows, columns = flight_data.shape
print(f"Number of rows: {rows}, Number of columns: {columns}")
# Out:
# Number of rows: 10683, Number of columns: 11

# %% [markdown]
# Q2. Distribution of Flight Prices:

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.figure(figsize=(10, 6))
plt.hist(flight_data['Price'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Flight Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Q3. Range of Prices in the Dataset:

# %%
# Minimum and maximum prices
min_price = flight_data['Price'].min()
max_price = flight_data['Price'].max()
print(f"Minimum Price: {min_price}, Maximum Price: {max_price}")
# Out:
# Minimum Price: 1759, Maximum Price: 79512

# %% [markdown]
# Q4. Price Variation by Airline - Boxplot:

# %%
import seaborn as sns

# Create a boxplot
plt.figure(figsize=(12, 8))
sns.boxplot(x='Airline', y='Price', data=flight_data)
plt.title('Flight Prices by Airline')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Q5. Identification of Outliers - Boxplot:

# %%
# Identify outliers
plt.figure(figsize=(10, 6))
sns.boxplot(x=flight_data['Price'])
plt.title('Identification of Outliers')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# Q6. Identifying Peak Travel Season:
#
# Features to Analyze:
#
# Date/Time: Analyze flight prices over different months or seasons.
# Destination: Prices may vary based on the popularity of destinations.
# Airline: Certain airlines might have peak seasons.
# Presentation:
#
# Create line charts showing price trends over months or seasons.
# Highlight peak seasons and provide insights on contributing factors.
# Q7. Identifying Trends in Flight Prices:
#
# Features to Analyze:
#
# Date/Time: Analyze trends over time, considering day of the week, month, or season.
# Route: Prices may vary based on specific routes.
# Booking Window: Explore if early or last-minute bookings impact prices.
# Visualizations:
#
# Time series line charts for price trends.
# Heatmaps for price variations based on routes and booking time.
# Q8. Factors Affecting Flight Prices for Airline Analysis:
#
# Features to Analyze:
#
# Route and Distance: Longer routes might have higher prices.
# Time of Booking: Prices may vary based on how far in advance tickets are booked.
# Aircraft Type: Different aircraft may have different cost structures.
# Presentation:
#
# Regression analysis to quantify the impact of each factor.
# Visualizations like bar charts or regression plots to highlight influential factors.

# %% [markdown]
# ### PLAYSTORE

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions:

# %%
import pandas as pd

# Assuming the dataset is in a CSV file named 'google_playstore.csv'
playstore_data = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# Examine dimensions
rows, columns = playstore_data.shape
print(f"Number of rows: {rows}, Number of columns: {columns}")
# Out:
# Number of rows: 10841, Number of columns: 13

# %% [markdown]
# Q10. Rating Variation by Category - Boxplot:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a boxplot
plt.figure(figsize=(14, 8))
sns.boxplot(x='Category', y='Rating', data=playstore_data)
plt.title('App Ratings by Category')
plt.xlabel('Category')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Q11. Identifying Missing Values:

# %%
# Check for missing values
missing_values = playstore_data.isnull().sum()

# Display the missing values
print(missing_values)
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# Q12. Relationship between App Size and Rating - Scatter Plot:

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(playstore_data['Size'], playstore_data['Rating'], alpha=0.5)
plt.title('Relationship between App Size and Rating')
plt.xlabel('App Size')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# Q13. Effect of App Type on Price - Bar Chart:

# %%
# Create a bar chart
"""avg_prices_by_type = playstore_data.groupby('Type')['Price'].mean()
avg_prices_by_type.plot(kind='bar', color=['skyblue', 'lightcoral'], figsize=(10, 6))
plt.title('Average Prices by App Type')
plt.xlabel('App Type')
plt.ylabel('Average Price')
plt.show()"""
# Out:
# "avg_prices_by_type = playstore_data.groupby('Type')['Price'].mean()\navg_prices_by_type.plot(kind='bar', color=['skyblue', 'lightcoral'], figsize=(10, 6))\nplt.title('Average Prices by App Type')\nplt.xlabel('App Type')\nplt.ylabel('Average Price')\nplt.show()"

# %% [markdown]
# Q14. Top 10 Most Popular Apps - Frequency Table:

# %%
# Create a frequency table
top_apps = playstore_data.nlargest(10, 'Installs')[['App', 'Installs']]

# Display the top apps
print(top_apps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Create a frequency table
# ----> 2 top_apps = playstore_data.nlargest(10, 'Installs')[['App', 'Installs']]
#       4 # Display the top apps
#       5 print(top_apps)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:7335, in DataFrame.nlargest(self, n, columns, keep)
#    7230 def nlargest(self, n: int, columns: IndexLabel, keep: str = "first") -> DataFrame:
#    7231     """
#    7232     Return the first `n` rows ordered by `columns` in descending order.
#    7233
#    (...)
#    7333     Brunei      434000    12128      BN
#    7334     """
# -> 7335     return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/algorithms.py:1273, in SelectN.nlargest(self)
#    1271 @final
# ...
